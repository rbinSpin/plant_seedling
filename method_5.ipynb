# %%
# import all we need
from matplotlib import image
from matplotlib import pyplot
import time
import os
import numpy as np
import glob
import shutil
import matplotlib.pyplot as plt
# %matplotlib inline
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
import matplotlib.pylab as plt
import tensorflow_hub as hub
import tensorflow_datasets as tfds
from tensorflow.keras import layers
import logging
logger = tf.get_logger()
logger.setLevel(logging.ERROR)
import sklearn
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score
import pandas as pd 
import cv2
from tqdm import tqdm
from imblearn.over_sampling import SMOTE, ADASYN
from tensorflow.keras import datasets, layers, models, losses, Model
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import multilabel_confusion_matrix
import seaborn as sns
from tensorflow.keras.regularizers import l2

# %%
# set up dir of data
base_dir = '../plant-seedlings-classification/data'
train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')
# the 12 species
classes = os.listdir(train_dir)
# parameter
batch_size = 32
IMG_SHAPE = 150

# %%
#read training set
for dirname, _, filenames in os.walk(train_dir):
    for filename in filenames:
        os.path.join(dirname, filename)

DATADIR = train_dir
classes = os.listdir(train_dir)
IMG_SIZE= IMG_SHAPE
CATEGORIES = classes

training_data=[]
def create_training_data():
    for category in CATEGORIES:
        path=os.path.join(DATADIR, category)
        class_num=CATEGORIES.index(category)
        for img in os.listdir(path):
            try:
                img_array=cv2.imread(os.path.join(path,img))
                new_array=cv2.resize(img_array,(IMG_SIZE,IMG_SIZE))
                training_data.append([new_array,class_num])
            except Exception as e:
                pass
create_training_data()
X=[]
y=[]

for categories, label in training_data:
    y.append(label)
    X.append(categories)

# %%
#read val set
for dirname, _, filenames in os.walk(val_dir):
    for filename in filenames:
        os.path.join(dirname, filename)

DATADIR = val_dir
classes = os.listdir(val_dir)
IMG_SIZE= IMG_SHAPE
CATEGORIES = classes

val_data=[]
def create_val_data():
    for category in CATEGORIES:
        path=os.path.join(DATADIR, category)
        class_num=CATEGORIES.index(category)
        for img in os.listdir(path):
            try:
                img_array=cv2.imread(os.path.join(path,img))
                new_array=cv2.resize(img_array,(IMG_SIZE,IMG_SIZE))
                val_data.append([new_array,class_num])
            except Exception as e:
                pass
create_val_data()
X_val=[]
y_val=[]

for categories, label in val_data:
    y_val.append(label)
    X_val.append(categories)

# %%
X=np.array(X)
y=np.array(y)
X_val=np.array(X_val)
y_val=np.array(y_val)

# %%
datagen = ImageDataGenerator(
                    rescale=1./255,
                    rotation_range=45,
                    width_shift_range=.15,
                    height_shift_range=.15,
                    horizontal_flip=True,
                    zoom_range=0.5
                    )
# compute quantities required for featurewise normalization
# (std, mean, and principal components if ZCA whitening is applied)
datagen.fit(X)
# fits the model on batches with real-time data augmentation:
train_data_gen = datagen.flow(X, 
                              y,
                              shuffle=True,
                              batch_size=batch_size)

# %%
image_gen_val = ImageDataGenerator(rescale=1./255)
image_gen_val.fit(X_val)
val_data_gen = image_gen_val.flow(X_val,
                                  y_val,
                                  batch_size=batch_size)

# %%
# model
model = Sequential()

model.add(Conv2D(16, (3,3), padding='same',strides=2, activation='relu', input_shape=(IMG_SHAPE,IMG_SHAPE, 3)))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, 3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, 3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dense(12, kernel_regularizer=tf.keras.regularizers.l2(0.01),activation
             ='linear'))

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 75, 75, 16)        448
#
#  max_pooling2d (MaxPooling2D  (None, 37, 37, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 37, 37, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 18, 18, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 18, 18, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 9, 9, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 5184)              0
#
#  dropout (Dropout)           (None, 5184)              0
#
#  dense (Dense)               (None, 512)               2654720
#
#  dense_1 (Dense)             (None, 12)                6156
#
# =================================================================
# Total params: 2,684,460
# Trainable params: 2,684,460
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 120

history = model.fit(
    train_data_gen,
    steps_per_epoch=int(np.ceil(train_data_gen.n / float(batch_size))),
    epochs=epochs,
    validation_data=val_data_gen,
    validation_steps=int(np.ceil(val_data_gen.n / float(batch_size)))
)
# Out:
# Epoch 1/120
# 119/119 [==============================] - 29s 230ms/step - loss: 2.4052 - accuracy: 0.1886 - val_loss: 1.9168 - val_accuracy: 0.3288
# Epoch 2/120
# 119/119 [==============================] - 28s 231ms/step - loss: 1.8618 - accuracy: 0.3528 - val_loss: 1.5541 - val_accuracy: 0.4773
# Epoch 3/120
# 119/119 [==============================] - 28s 235ms/step - loss: 1.6243 - accuracy: 0.4336 - val_loss: 1.5082 - val_accuracy: 0.4700
# Epoch 4/120
# 119/119 [==============================] - 29s 243ms/step - loss: 1.4845 - accuracy: 0.4865 - val_loss: 1.5536 - val_accuracy: 0.4531
# Epoch 5/120
# 119/119 [==============================] - 30s 248ms/step - loss: 1.4086 - accuracy: 0.5222 - val_loss: 1.1640 - val_accuracy: 0.6217
# Epoch 6/120
# 119/119 [==============================] - 28s 237ms/step - loss: 1.3593 - accuracy: 0.5346 - val_loss: 1.0603 - val_accuracy: 0.6396
# Epoch 7/120
# 119/119 [==============================] - 29s 246ms/step - loss: 1.2819 - accuracy: 0.5649 - val_loss: 0.9504 - val_accuracy: 0.6923
# Epoch 8/120
# 119/119 [==============================] - 29s 242ms/step - loss: 1.2210 - accuracy: 0.5872 - val_loss: 1.0608 - val_accuracy: 0.6459
# Epoch 9/120
# 119/119 [==============================] - 29s 242ms/step - loss: 1.1624 - accuracy: 0.6119 - val_loss: 1.0188 - val_accuracy: 0.6396
# Epoch 10/120
# 119/119 [==============================] - 29s 241ms/step - loss: 1.1446 - accuracy: 0.6219 - val_loss: 0.8536 - val_accuracy: 0.7250
# Epoch 11/120
# 119/119 [==============================] - 29s 247ms/step - loss: 1.0346 - accuracy: 0.6632 - val_loss: 0.7937 - val_accuracy: 0.7408
# Epoch 12/120
# 119/119 [==============================] - 33s 279ms/step - loss: 1.0142 - accuracy: 0.6630 - val_loss: 0.7972 - val_accuracy: 0.7197
# Epoch 13/120
# 119/119 [==============================] - 30s 254ms/step - loss: 0.9913 - accuracy: 0.6732 - val_loss: 0.7186 - val_accuracy: 0.7692
# Epoch 14/120
# 119/119 [==============================] - 33s 280ms/step - loss: 0.9959 - accuracy: 0.6730 - val_loss: 0.7911 - val_accuracy: 0.7313
# Epoch 15/120
# 119/119 [==============================] - 32s 268ms/step - loss: 0.9456 - accuracy: 0.6967 - val_loss: 0.6595 - val_accuracy: 0.7893
# Epoch 16/120
# 119/119 [==============================] - 32s 271ms/step - loss: 0.9059 - accuracy: 0.7124 - val_loss: 0.6150 - val_accuracy: 0.8082
# Epoch 17/120
# 119/119 [==============================] - 31s 261ms/step - loss: 0.8804 - accuracy: 0.7153 - val_loss: 0.7401 - val_accuracy: 0.7587
# Epoch 18/120
# 119/119 [==============================] - 31s 262ms/step - loss: 0.8555 - accuracy: 0.7251 - val_loss: 0.5898 - val_accuracy: 0.8188
# Epoch 19/120
# 119/119 [==============================] - 31s 261ms/step - loss: 0.8581 - accuracy: 0.7201 - val_loss: 0.6172 - val_accuracy: 0.8082
# Epoch 20/120
# 119/119 [==============================] - 32s 266ms/step - loss: 0.8307 - accuracy: 0.7256 - val_loss: 0.5842 - val_accuracy: 0.8135
# Epoch 21/120
# 119/119 [==============================] - 32s 267ms/step - loss: 0.8171 - accuracy: 0.7316 - val_loss: 0.6374 - val_accuracy: 0.7935
# Epoch 22/120
# 119/119 [==============================] - 33s 280ms/step - loss: 0.7829 - accuracy: 0.7443 - val_loss: 0.5598 - val_accuracy: 0.8230
# Epoch 23/120
# 119/119 [==============================] - 31s 262ms/step - loss: 0.7727 - accuracy: 0.7524 - val_loss: 0.4922 - val_accuracy: 0.8367
# Epoch 24/120
# 119/119 [==============================] - 31s 263ms/step - loss: 0.7485 - accuracy: 0.7574 - val_loss: 0.4880 - val_accuracy: 0.8377
# Epoch 25/120
# 119/119 [==============================] - 31s 261ms/step - loss: 0.7322 - accuracy: 0.7593 - val_loss: 0.6088 - val_accuracy: 0.7935
# Epoch 26/120
# 119/119 [==============================] - 31s 261ms/step - loss: 0.7194 - accuracy: 0.7716 - val_loss: 0.4404 - val_accuracy: 0.8757
# Epoch 27/120
# 119/119 [==============================] - 31s 264ms/step - loss: 0.6781 - accuracy: 0.7837 - val_loss: 0.4649 - val_accuracy: 0.8504
# Epoch 28/120
# 119/119 [==============================] - 34s 282ms/step - loss: 0.6889 - accuracy: 0.7761 - val_loss: 0.4426 - val_accuracy: 0.8662
# Epoch 29/120
# 119/119 [==============================] - 32s 266ms/step - loss: 0.6451 - accuracy: 0.7861 - val_loss: 0.5361 - val_accuracy: 0.8230
# Epoch 30/120
# 119/119 [==============================] - 32s 271ms/step - loss: 0.6785 - accuracy: 0.7819 - val_loss: 0.4978 - val_accuracy: 0.8419
# Epoch 31/120
# 119/119 [==============================] - 34s 286ms/step - loss: 0.6585 - accuracy: 0.7937 - val_loss: 0.4068 - val_accuracy: 0.8778
# Epoch 32/120
# 119/119 [==============================] - 33s 278ms/step - loss: 0.6302 - accuracy: 0.7974 - val_loss: 0.4144 - val_accuracy: 0.8736
# Epoch 33/120
# 119/119 [==============================] - 33s 279ms/step - loss: 0.6048 - accuracy: 0.8024 - val_loss: 0.4795 - val_accuracy: 0.8440
# Epoch 34/120
# 119/119 [==============================] - 32s 271ms/step - loss: 0.6542 - accuracy: 0.7840 - val_loss: 0.5273 - val_accuracy: 0.8251
# Epoch 35/120
# 119/119 [==============================] - 31s 260ms/step - loss: 0.6014 - accuracy: 0.8111 - val_loss: 0.4112 - val_accuracy: 0.8778
# Epoch 36/120
# 119/119 [==============================] - 31s 261ms/step - loss: 0.5618 - accuracy: 0.8243 - val_loss: 0.4111 - val_accuracy: 0.8630
# Epoch 37/120
# 119/119 [==============================] - 31s 261ms/step - loss: 0.5972 - accuracy: 0.8045 - val_loss: 0.5625 - val_accuracy: 0.8219
# Epoch 38/120
# 119/119 [==============================] - 31s 262ms/step - loss: 0.5750 - accuracy: 0.8119 - val_loss: 0.4533 - val_accuracy: 0.8514
# Epoch 39/120
# 119/119 [==============================] - 31s 260ms/step - loss: 0.5901 - accuracy: 0.8061 - val_loss: 0.4533 - val_accuracy: 0.8462
# Epoch 40/120
# 119/119 [==============================] - 32s 271ms/step - loss: 0.5391 - accuracy: 0.8232 - val_loss: 0.3654 - val_accuracy: 0.8820
# Epoch 41/120
# 119/119 [==============================] - 34s 288ms/step - loss: 0.5451 - accuracy: 0.8282 - val_loss: 0.3763 - val_accuracy: 0.8778
# Epoch 42/120
# 119/119 [==============================] - 35s 293ms/step - loss: 0.5479 - accuracy: 0.8235 - val_loss: 0.3499 - val_accuracy: 0.8894
# Epoch 43/120
# 119/119 [==============================] - 34s 284ms/step - loss: 0.5418 - accuracy: 0.8211 - val_loss: 0.3704 - val_accuracy: 0.8725
# Epoch 44/120
# 119/119 [==============================] - 31s 258ms/step - loss: 0.5300 - accuracy: 0.8264 - val_loss: 0.3709 - val_accuracy: 0.8778
# Epoch 45/120
# 119/119 [==============================] - 32s 269ms/step - loss: 0.5074 - accuracy: 0.8353 - val_loss: 0.3591 - val_accuracy: 0.8851
# Epoch 46/120
# 119/119 [==============================] - 32s 268ms/step - loss: 0.4793 - accuracy: 0.8453 - val_loss: 0.3652 - val_accuracy: 0.8883
# Epoch 47/120
# 119/119 [==============================] - 33s 276ms/step - loss: 0.5150 - accuracy: 0.8343 - val_loss: 0.3486 - val_accuracy: 0.8862
# Epoch 48/120
# 119/119 [==============================] - 32s 272ms/step - loss: 0.4783 - accuracy: 0.8414 - val_loss: 0.3249 - val_accuracy: 0.8999
# Epoch 49/120
# 119/119 [==============================] - 32s 272ms/step - loss: 0.4736 - accuracy: 0.8514 - val_loss: 0.3300 - val_accuracy: 0.9020
# Epoch 50/120
# 119/119 [==============================] - 32s 270ms/step - loss: 0.4891 - accuracy: 0.8495 - val_loss: 0.3473 - val_accuracy: 0.8904
# Epoch 51/120
# 119/119 [==============================] - 38s 319ms/step - loss: 0.4863 - accuracy: 0.8432 - val_loss: 0.4633 - val_accuracy: 0.8409
# Epoch 52/120
# 119/119 [==============================] - 36s 305ms/step - loss: 0.4689 - accuracy: 0.8503 - val_loss: 0.3623 - val_accuracy: 0.8915
# Epoch 53/120
# 119/119 [==============================] - 34s 283ms/step - loss: 0.4406 - accuracy: 0.8621 - val_loss: 0.3511 - val_accuracy: 0.8894
# Epoch 54/120
# 119/119 [==============================] - 40s 336ms/step - loss: 0.4612 - accuracy: 0.8458 - val_loss: 0.3978 - val_accuracy: 0.8651
# Epoch 55/120
# 119/119 [==============================] - 35s 292ms/step - loss: 0.4231 - accuracy: 0.8674 - val_loss: 0.3620 - val_accuracy: 0.8672
# Epoch 56/120
# 119/119 [==============================] - 38s 316ms/step - loss: 0.4265 - accuracy: 0.8648 - val_loss: 0.3222 - val_accuracy: 0.8925
# Epoch 57/120
# 119/119 [==============================] - 32s 267ms/step - loss: 0.4148 - accuracy: 0.8706 - val_loss: 0.3544 - val_accuracy: 0.8915
# Epoch 58/120
# 119/119 [==============================] - 32s 268ms/step - loss: 0.4242 - accuracy: 0.8656 - val_loss: 0.2859 - val_accuracy: 0.9073
# Epoch 59/120
# 119/119 [==============================] - 32s 270ms/step - loss: 0.4262 - accuracy: 0.8706 - val_loss: 0.2957 - val_accuracy: 0.9052
# Epoch 60/120
# 119/119 [==============================] - 34s 286ms/step - loss: 0.4241 - accuracy: 0.8627 - val_loss: 0.3398 - val_accuracy: 0.8799
# Epoch 61/120
# 119/119 [==============================] - 32s 267ms/step - loss: 0.4062 - accuracy: 0.8690 - val_loss: 0.4147 - val_accuracy: 0.8662
# Epoch 62/120
# 119/119 [==============================] - 34s 285ms/step - loss: 0.4101 - accuracy: 0.8677 - val_loss: 0.2849 - val_accuracy: 0.9168
# Epoch 63/120
# 119/119 [==============================] - 34s 283ms/step - loss: 0.3992 - accuracy: 0.8742 - val_loss: 0.4442 - val_accuracy: 0.8504
# Epoch 64/120
# 119/119 [==============================] - 33s 277ms/step - loss: 0.4060 - accuracy: 0.8711 - val_loss: 0.3608 - val_accuracy: 0.8704
# Epoch 65/120
# 119/119 [==============================] - 33s 278ms/step - loss: 0.4036 - accuracy: 0.8756 - val_loss: 0.3099 - val_accuracy: 0.8967
# Epoch 66/120
# 119/119 [==============================] - 32s 271ms/step - loss: 0.3929 - accuracy: 0.8756 - val_loss: 0.3462 - val_accuracy: 0.8862
# Epoch 67/120
# 119/119 [==============================] - 32s 272ms/step - loss: 0.3898 - accuracy: 0.8753 - val_loss: 0.2592 - val_accuracy: 0.9178
# Epoch 68/120
# 119/119 [==============================] - 35s 296ms/step - loss: 0.3828 - accuracy: 0.8792 - val_loss: 0.2956 - val_accuracy: 0.9146
# Epoch 69/120
# 119/119 [==============================] - 35s 291ms/step - loss: 0.3948 - accuracy: 0.8687 - val_loss: 0.2765 - val_accuracy: 0.9136
# Epoch 70/120
# 119/119 [==============================] - 32s 265ms/step - loss: 0.3743 - accuracy: 0.8829 - val_loss: 0.3094 - val_accuracy: 0.9031
# Epoch 71/120
# 119/119 [==============================] - 31s 259ms/step - loss: 0.3751 - accuracy: 0.8816 - val_loss: 0.2637 - val_accuracy: 0.9210
# Epoch 72/120
# 119/119 [==============================] - 31s 257ms/step - loss: 0.3537 - accuracy: 0.8919 - val_loss: 0.3053 - val_accuracy: 0.9104
# Epoch 73/120
# 119/119 [==============================] - 33s 277ms/step - loss: 0.3663 - accuracy: 0.8871 - val_loss: 0.2995 - val_accuracy: 0.9094
# Epoch 74/120
# 119/119 [==============================] - 37s 308ms/step - loss: 0.3723 - accuracy: 0.8856 - val_loss: 0.2467 - val_accuracy: 0.9252
# Epoch 75/120
# 119/119 [==============================] - 39s 325ms/step - loss: 0.3702 - accuracy: 0.8829 - val_loss: 0.3583 - val_accuracy: 0.8757
# Epoch 76/120
# 119/119 [==============================] - 37s 310ms/step - loss: 0.3869 - accuracy: 0.8798 - val_loss: 0.2989 - val_accuracy: 0.8978
# Epoch 77/120
# 119/119 [==============================] - 36s 300ms/step - loss: 0.3558 - accuracy: 0.8785 - val_loss: 0.3575 - val_accuracy: 0.8778
# Epoch 78/120
# 119/119 [==============================] - 37s 304ms/step - loss: 0.3438 - accuracy: 0.8858 - val_loss: 0.3901 - val_accuracy: 0.8757
# Epoch 79/120
# 119/119 [==============================] - 33s 277ms/step - loss: 0.3597 - accuracy: 0.8874 - val_loss: 0.2761 - val_accuracy: 0.9115
# Epoch 80/120
# 119/119 [==============================] - 33s 275ms/step - loss: 0.3506 - accuracy: 0.8840 - val_loss: 0.2605 - val_accuracy: 0.9157
# Epoch 81/120
# 119/119 [==============================] - 33s 274ms/step - loss: 0.3561 - accuracy: 0.8861 - val_loss: 0.3087 - val_accuracy: 0.8936
# Epoch 82/120
# 119/119 [==============================] - 33s 273ms/step - loss: 0.3531 - accuracy: 0.8871 - val_loss: 0.2992 - val_accuracy: 0.8988
# Epoch 83/120
# 119/119 [==============================] - 32s 271ms/step - loss: 0.3263 - accuracy: 0.8992 - val_loss: 0.2352 - val_accuracy: 0.9336
# Epoch 84/120
# 119/119 [==============================] - 35s 294ms/step - loss: 0.2986 - accuracy: 0.9077 - val_loss: 0.2578 - val_accuracy: 0.9199
# Epoch 85/120
# 119/119 [==============================] - 33s 277ms/step - loss: 0.3513 - accuracy: 0.8869 - val_loss: 0.2361 - val_accuracy: 0.9315
# Epoch 86/120
# 119/119 [==============================] - 32s 269ms/step - loss: 0.3201 - accuracy: 0.8992 - val_loss: 0.2618 - val_accuracy: 0.9178
# Epoch 87/120
# 119/119 [==============================] - 32s 269ms/step - loss: 0.3242 - accuracy: 0.8974 - val_loss: 0.2563 - val_accuracy: 0.9231
# Epoch 88/120
# 119/119 [==============================] - 33s 275ms/step - loss: 0.3264 - accuracy: 0.8945 - val_loss: 0.2355 - val_accuracy: 0.9210
# Epoch 89/120
# 119/119 [==============================] - 32s 267ms/step - loss: 0.3180 - accuracy: 0.9029 - val_loss: 0.2325 - val_accuracy: 0.9305
# Epoch 90/120
# 119/119 [==============================] - 33s 274ms/step - loss: 0.3362 - accuracy: 0.8892 - val_loss: 0.2266 - val_accuracy: 0.9336
# Epoch 91/120
# 119/119 [==============================] - 33s 274ms/step - loss: 0.3408 - accuracy: 0.8916 - val_loss: 0.2430 - val_accuracy: 0.9252
# Epoch 92/120
# 119/119 [==============================] - 32s 268ms/step - loss: 0.3351 - accuracy: 0.8906 - val_loss: 0.2180 - val_accuracy: 0.9315
# Epoch 93/120
# 119/119 [==============================] - 33s 274ms/step - loss: 0.3141 - accuracy: 0.8992 - val_loss: 0.2338 - val_accuracy: 0.9231
# Epoch 94/120
# 119/119 [==============================] - 32s 268ms/step - loss: 0.3120 - accuracy: 0.8937 - val_loss: 0.3316 - val_accuracy: 0.9062
# Epoch 95/120
# 119/119 [==============================] - 32s 264ms/step - loss: 0.3382 - accuracy: 0.8924 - val_loss: 0.2736 - val_accuracy: 0.9146
# Epoch 96/120
# 119/119 [==============================] - 31s 260ms/step - loss: 0.3151 - accuracy: 0.8961 - val_loss: 0.2400 - val_accuracy: 0.9294
# Epoch 97/120
# 119/119 [==============================] - 32s 270ms/step - loss: 0.2999 - accuracy: 0.9050 - val_loss: 0.2394 - val_accuracy: 0.9210
# Epoch 98/120
# 119/119 [==============================] - 33s 276ms/step - loss: 0.3188 - accuracy: 0.8963 - val_loss: 0.2313 - val_accuracy: 0.9336
# Epoch 99/120
# 119/119 [==============================] - 34s 286ms/step - loss: 0.3167 - accuracy: 0.8990 - val_loss: 0.2194 - val_accuracy: 0.9326
# Epoch 100/120
# 119/119 [==============================] - 35s 293ms/step - loss: 0.3135 - accuracy: 0.9053 - val_loss: 0.2231 - val_accuracy: 0.9305
# Epoch 101/120
# 119/119 [==============================] - 32s 268ms/step - loss: 0.2866 - accuracy: 0.9084 - val_loss: 0.2542 - val_accuracy: 0.9231
# Epoch 102/120
# 119/119 [==============================] - 33s 273ms/step - loss: 0.2947 - accuracy: 0.9074 - val_loss: 0.2145 - val_accuracy: 0.9273
# Epoch 103/120
# 119/119 [==============================] - 32s 269ms/step - loss: 0.3121 - accuracy: 0.8956 - val_loss: 0.2652 - val_accuracy: 0.9157
# Epoch 104/120
# 119/119 [==============================] - 32s 268ms/step - loss: 0.2867 - accuracy: 0.9098 - val_loss: 0.3432 - val_accuracy: 0.8851
# Epoch 105/120
# 119/119 [==============================] - 33s 281ms/step - loss: 0.2998 - accuracy: 0.9019 - val_loss: 0.2330 - val_accuracy: 0.9357
# Epoch 106/120
# 119/119 [==============================] - 31s 263ms/step - loss: 0.3009 - accuracy: 0.9027 - val_loss: 0.2723 - val_accuracy: 0.9168
# Epoch 107/120
# 119/119 [==============================] - 31s 263ms/step - loss: 0.2808 - accuracy: 0.9155 - val_loss: 0.3519 - val_accuracy: 0.8936
# Epoch 108/120
# 119/119 [==============================] - 31s 262ms/step - loss: 0.3008 - accuracy: 0.9000 - val_loss: 0.2309 - val_accuracy: 0.9283
# Epoch 109/120
# 119/119 [==============================] - 31s 263ms/step - loss: 0.2832 - accuracy: 0.9050 - val_loss: 0.2170 - val_accuracy: 0.9347
# Epoch 110/120
# 119/119 [==============================] - 32s 265ms/step - loss: 0.3123 - accuracy: 0.8990 - val_loss: 0.4145 - val_accuracy: 0.8746
# Epoch 111/120
# 119/119 [==============================] - 34s 283ms/step - loss: 0.2922 - accuracy: 0.9053 - val_loss: 0.2425 - val_accuracy: 0.9283
# Epoch 112/120
# 119/119 [==============================] - 32s 271ms/step - loss: 0.2820 - accuracy: 0.9074 - val_loss: 0.3044 - val_accuracy: 0.9157
# Epoch 113/120
# 119/119 [==============================] - 33s 277ms/step - loss: 0.3100 - accuracy: 0.9034 - val_loss: 0.3300 - val_accuracy: 0.8820
# Epoch 114/120
# 119/119 [==============================] - 33s 278ms/step - loss: 0.2952 - accuracy: 0.9079 - val_loss: 0.2698 - val_accuracy: 0.9199
# Epoch 115/120
# 119/119 [==============================] - 35s 290ms/step - loss: 0.2957 - accuracy: 0.9003 - val_loss: 0.2889 - val_accuracy: 0.9125
# Epoch 116/120
# 119/119 [==============================] - 36s 301ms/step - loss: 0.2747 - accuracy: 0.9132 - val_loss: 0.2660 - val_accuracy: 0.9157
# Epoch 117/120
# 119/119 [==============================] - 33s 275ms/step - loss: 0.2873 - accuracy: 0.9082 - val_loss: 0.2182 - val_accuracy: 0.9336
# Epoch 118/120
# 119/119 [==============================] - 35s 290ms/step - loss: 0.2840 - accuracy: 0.9129 - val_loss: 0.2952 - val_accuracy: 0.9136
# Epoch 119/120
# 119/119 [==============================] - 35s 291ms/step - loss: 0.2554 - accuracy: 0.9208 - val_loss: 0.2919 - val_accuracy: 0.9115
# Epoch 120/120
# 119/119 [==============================] - 35s 292ms/step - loss: 0.2817 - accuracy: 0.9105 - val_loss: 0.3310 - val_accuracy: 0.8957

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
t = time.time()

export_path_keras = "./M1_1/{}.h5".format(int(t))
print(export_path_keras)

model.save(export_path_keras)
# Out:
# ./M1_1/1672658570.h5

# %%
# reload
reloaded = tf.keras.models.load_model(
  './M1_1/1672658570.h5', 
  # `custom_objects` tells keras how to load a `hub.KerasLayer`
  custom_objects={'KerasLayer': hub.KerasLayer})

# %%
# predict the testdata
test_dir = '../plant-seedlings-classification/test'
testdata_dir = test_dir + '/testdata'
le = LabelEncoder()
le.fit(os.listdir(train_dir))
testdata = os.listdir(testdata_dir)
test_tal_num = 0
im = []
allimages= []
img_path = os.path.join(test_dir, 'testdata')
images = glob.glob(img_path + '/*.png')
allimages.extend(images)
#print("{}: {} Images".format(cl, len(images)))
test_tal_num += len(images)
#num_train = int(round(len(images)*0.8))
#train, val = images[:num_train], images[num_train:]
for i in range(len(images)):
    img = cv2.imread(allimages[i])
    img = tf.image.resize(img, [150,150])
    im.append(img)
im = np.array(im)/255.0
predictions = reloaded.predict(im)
# Out:
# 25/25 [==============================] - 1s 23ms/step

# %%
results = []
for i in range(predictions.shape[0]):
    results.append(np.argmax(predictions[i]))
PredStr = list(le.inverse_transform(results))
result = {'file':testdata,'species':PredStr}
result = pd.DataFrame(result)
result.to_csv("Prediction_M1_1.csv",index=False)
#score : 0.94

# %%
# confution matrix
X_val = X_val/255
prediction_val = reloaded.predict(X_val)
results_val = []
for i in range(prediction_val.shape[0]):
    results_val.append(np.argmax(prediction_val[i]))
# Creating  a confusion matrix,which compares the y_test and y_pred
cm = confusion_matrix(y_val, results_val)
cm_df = pd.DataFrame(cm,
                     index = classes, 
                     columns = classes)
#Plotting the confusion matrix
plt.figure(figsize=(5,4))
sns.heatmap(cm_df, annot=True)
plt.title('Confusion Matrix')
plt.ylabel('Actal Values')
plt.xlabel('Predicted Values')
plt.show()
# Out:
# 30/30 [==============================] - 1s 21ms/step
